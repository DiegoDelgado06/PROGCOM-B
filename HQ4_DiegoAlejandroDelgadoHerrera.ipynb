# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoDelgado06/PROGCOM-B/blob/main/HQ4_DiegoAlejandroDelgadoHerrera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###HARDCORE QUEST FOUR HQ4

# %%
import random
import time
import ipywidgets as widgets
from IPython.display import display, clear_output
data = {
    "Nombre": [
        "Andrés","Beatriz","Carlos","Diana","Elena","Fernando","Gabriela","Hernán","Isabel","Jorge",
        "Karen","Luis","María","Natalia","Oscar","Pedro","Raúl","Sofía","Tomás","Valeria",
        "Walter","Ximena","Yolanda","Zacarías","Alejandro","Brenda","Camilo","Daniela","Esteban",
        "Federico","Gloria","Hugo","Iván","Juliana","Kevin","Laura","Manuel","Nicolás","Olga",
        "Patricia","Quique","Rosa","Sebastián","Tatiana","Ulises","Verónica","Wendy","Yulieth","Zoila",
        "Amparo","Bernardo","Claudia","Diego","Emilio","Fabiola","Germán","Helena","Inés","Julián",
        "Katerine","Leonardo","Marta","Norberto","Orlando","Paola","Ramiro","Samuel","Teresa","Uriel",
        "Viviana","Wilmer","Yohana","Zulema","Andrea","Boris","Cristina","Domingo","Efraín","Felipe",
        "Guillermo","Herminia","Ignacio","Jimena","Katya","Lorena","Marcela","Nadia","Octavio","Priscila",
        "Rafael","Susana","Tobías","Victoria","Xavier","Yenny","Zoar"
    ],
    "Apellido": [
        "Alvarez","Benítez","Castro","Domínguez","Espinosa","Fernández","Gómez","Hernández","Ibarra","Jiménez",
        "López","Martínez","Núñez","Ortega","Pérez","Quintero","Ramírez","Sánchez","Torres","Uribe",
        "Valenzuela","Zamora","Arango","Bermúdez","Cárdenas","Delgado","Escobar","Flórez","Gutiérrez","Hoyos",
        "Izquierdo","Jaramillo","Ladino","Montoya","Nieto","Osorio","Patiño","Quiroga","Ríos","Suárez",
        "Téllez","Useche","Velásquez","Yepes","Zapata","Acevedo","Barrera","Calderón","Durán","Enríquez",
        "Forero","Galindo","Holguín","Jaimes","Londoño","Moreno","Navarro","Ocampo","Palacios","Reyes",
        "Salazar","Tamayo","Urrego","Vargas","Zúñiga","Arias","Buitrago","Castaño","Cuesta","Duarte",
        "Franco","Guerrero","Lozano","Mejía","Parra","Quiceno","Rendón","Sierra","Trujillo","Valencia",
        "Álvarez","Camacho","Córdoba","Restrepo","Serna"
    ],
    "Ciudad": [
        "Bogotá","Bucaramanga","Cali","Cartagena","Medellín","Pereira","Cúcuta","Ibagué","Manizales","Neiva",
        "Villavicencio","Tunja","Barranquilla","Sincelejo","Montería","Santa Marta","Riohacha","Armenia",
        "Popayán","Pamplona","Girón","Floridablanca","Piedecuesta","Soacha","Zipaquirá","Fusagasugá","Yopal",
        "Arauca","Leticia","San Andrés","Quibdó","Mocoa","Mitú","Puerto Carreño","Chía","Mosquera","Funza",
        "Sogamoso","Duitama","Ocaña","Ciénaga","Turbo","Apartadó","Ipiales","Pasto","Tuluá","Palmira","Jamundí",
        "Soledad","Malambo","Galapa","Baranoa","Envigado","Itagüí","Bello","Rionegro","La Ceja","Copacabana",
        "Cajicá","Tabio","Tenjo","Madrid","Facatativá","Chocontá","Zarzal","Cartago","La Dorada","Honda",
        "San Gil","Socorro","Barichara","Charalá"
    ],
    "Animal": [
        "Águila","Ballena","Caballo","Delfín","Elefante","Flamenco","Gato","Hiena","Iguana","Jaguar",
        "Koala","León","Mono","Nutria","Oso","Perro","Quetzal","Rinoceronte","Serpiente","Tigre",
        "Urraca","Vaca","Zorro","Ardilla","Burro","Canguro","Dromedario","Erizo","Foca","Gorila",
        "Halcon","Insecto","Jirafa","Lagarto","Murciélago","Ñandú","Orangután","Puma","Quimera","Rana",
        "Sapo","Tapir","Unicornio","Venado","Wombat","Yak","Zebra","Avispa","Búho","Camello","Dragón",
        "Escorpión","Gallina","Hormiga","Jabalí","Kiwi","Lobo","Mariposa","Narval","Orca","Pato","Quokka",
        "Ratón","Salamandra","Toro","Uakari","Vicuña","Wallaby","Xoloitzcuintle","Yakutiano","Zorrillo"
    ],
    "Fruta": [
        "Aguacate","Banano","Cereza","Durazno","Fresa","Granada","Higo","Kiwi","Limón","Mango",
        "Naranja","Papaya","Sandía","Tamarindo","Uva","Zapote","Ananá","Badea","Ciruela","Dátil",
        "Feijoa","Guayaba","Icaco","Jocote","Kumquat","Lichi","Mandarina","Níspero","Oliva","Pitahaya",
        "Quenepa","Rambután","Sapote","Toronja","Uchuva","Vainilla","Xoconostle","Yaca","Zarzamora"
    ],
    "País": [
        "Argentina","Brasil","Chile","Colombia","Dinamarca","Ecuador","Francia","Alemania","Italia","Japón",
        "Kenia","Luxemburgo","México","Noruega","Panamá","Perú","Qatar","Rusia","Suecia","Turquía",
        "Uruguay","Venezuela","Zimbabue","Australia","Bolivia","Canadá","Estados Unidos","Filipinas","Grecia",
        "Hungría","India","Jordania","Kosovo","Letonia","Marruecos","Nigeria","Omán","Polonia","Reino Unido",
        "Singapur","Tailandia","Ucrania","Vietnam","Yemen","Zambia"
    ],
    "Color": [
        "Amarillo","Azul","Blanco","Café","Celeste","Dorado","Gris","Morado","Naranja","Negro",
        "Plateado","Rojo","Rosado","Turquesa","Verde","Beige","Coral","Fucsia","Lavanda","Marrón",
        "Ocre","Perla","Vino tinto","Índigo","Esmeralda","Mostaza","Verde oliva","Cian","Magenta","Verde limón"
    ],
    "Comida": [
        "Arroz","Bandeja paisa","Carne asada","Changua","Empanada","Frijoles","Hamburguesa","Hot dog","Lasaña","Mazorca",
        "Nachos","Paella","Pizza","Quesadilla","Ravioles","Sancocho","Tacos","Tamales","Arepa","Caldo de pollo",
        "Ceviche","Churrasco","Ajiaco","Cazuela","Fajitas","Pollo asado","Ensalada","Sushi","Shawarma","Gazpacho",
        "Hummus","Risotto","Cuscús","Canelones","Tortilla","Polenta","Guiso","Estofado","Arequipe","Brownie"
    ]
}
def filtrar_palabras_por_letra(letra, lista):
    return [pal for pal in lista if pal[0].upper() == letra]
def jugar_ronda(letra, dificultad):
    clear_output()
    print(f"LETRA DE ESTA RONDA: {letra}")
    if dificultad == "Fácil":
        delay = random.uniform(8,10)
    elif dificultad == "Normal":
        delay = random.uniform(5,8)
    else:
        delay = random.uniform(3,3.5)
    respuestas_usuario = {}
    respuestas_maquina = {}
    puntaje_usuario = 0
    puntaje_maquina = 0
    for categoria in data.keys():
        entrada = input(f"Ingrese una {categoria} con {letra}: ").capitalize().strip()
        if entrada in filtrar_palabras_por_letra(letra, data[categoria]):
            print(f"Correcto en {categoria}")
            respuestas_usuario[categoria] = entrada
            puntaje_usuario += 100
        else:
            print(f"{entrada} no es válido en {categoria}")
            respuestas_usuario[categoria] = entrada
    print("\n esperate que la máquina está respondiendo")
    time.sleep(delay)
    for categoria in data.keys():
        opciones = filtrar_palabras_por_letra(letra, data[categoria])
        if opciones:
            eleccion = random.choice(opciones)
            respuestas_maquina[categoria] = eleccion
            puntaje_maquina += 100
        else:
            respuestas_maquina[categoria] = "---"
    print("\n=== RESULTADOS DE LA RONDA ===")
    print("Tus respuestas:")
    for cat, val in respuestas_usuario.items():
        print(f"{cat}: {val}")
    print("\nRespuestas de la máquina:")
    for cat, val in respuestas_maquina.items():
        print(f"{cat}: {val}")
    print(f"\nPuntaje Usuario: {puntaje_usuario}")
    print(f"Puntaje Máquina: {puntaje_maquina}")
    if puntaje_usuario > puntaje_maquina:
        print("Ganaste esta ronda bro")
    elif puntaje_usuario < puntaje_maquina:
        print("La máquina te ganó esta ronda jaja.")
    else:
        print("Empate")
def iniciar_juego():
    print("Bienvenido a mi juego de STOP")
    dificultad = input("Elige la dificultad (Fácil / Normal / Are you crazy?): ").capitalize()
    while True:
        letra = random.choice("ABCDEFGHIJKLMNÑOPQRSTUVWXYZ")
        jugar_ronda(letra, dificultad)
        seguir = input("\n¿Quieres jugar otra ronda bro? (s/n): ").lower()
        if seguir != "s":
            break
iniciar_juego()
# Out:
# LETRA DE ESTA RONDA: B
# Ingrese una Nombre con B: Bb
# Bb no es válido en Nombre
# Ingrese una Apellido con B: blanco
# Blanco no es válido en Apellido
# Ingrese una Ciudad con B: barcelona
# Barcelona no es válido en Ciudad
# Ingrese una Animal con B: buho
# Buho no es válido en Animal
# Ingrese una Fruta con B: banano
# Correcto en Fruta
# Ingrese una País con B: babilonia
# Babilonia no es válido en País
# Ingrese una Color con B: blanco
# Correcto en Color
# Ingrese una Comida con B: bagre
# Bagre no es válido en Comida
#
#  esperate que la máquina está respondiendo
#
# === RESULTADOS DE LA RONDA ===
# Tus respuestas:
# Nombre: Bb
# Apellido: Blanco
# Ciudad: Barcelona
# Animal: Buho
# Fruta: Banano
# País: Babilonia
# Color: Blanco
# Comida: Bagre
#
# Respuestas de la máquina:
# Nombre: Brenda
# Apellido: Benítez
# Ciudad: Bello
# Animal: Burro
# Fruta: Badea
# País: Brasil
# Color: Beige
# Comida: Brownie
#
# Puntaje Usuario: 200
# Puntaje Máquina: 800
# ...
