# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoDelgado06/PROGCOM-B/blob/main/clase28oct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Casa:
    def __init__(self,color,num_habitaciones,num_baños,tiene_patio,tiene_parqueadero):
     """
     Constructor de la clase casa
     Argumentos:
     color(str): definir el color de la casa
     num_habitaciones(int): definir el numero de habitaciones de la casa
     num_baños(int): numero de baños
     tiene_patio(bool): si tiene o no un patio
     tiene_parqueadero(bool): si tiene o no un parqueadero
    """
     self.color=color
     self.num_habitaciones=num_habitaciones
     self.num_baños=num_baños
     self.tiene_patio=tiene_patio
     self.tiene_parqueadero=tiene_parqueadero

    def describir(self):
     """
     Metodo para describir la casa
     """
     descripcion=f"La casa es de color {self.color}."

     if self.tiene_patio:
      descripcion+="/nLa casa posee un patio."
     if self.tiene_parqueadero:
      descripcion+="/nLa casa posee un parqueadero."
     return descripcion

# %%
mi_casa=Casa("Roja con blanco", 5, 2, True, True)
type(mi_casa)
# Out:
# __main__.Casa

# %%
mi_casa.describir()
# Out:
# 'La casa es de color Roja con blanco./nLa casa posee un patio./nLa casa posee un parqueadero.'

# %%
print(mi_casa.describir())
# Out:
# La casa es de color Roja con blanco./nLa casa posee un patio./nLa casa posee un parqueadero.

# %%
class Floristeria(Casa): #Herencia
 def __init__(self,color,num_habitaciones,num_baños,tiene_patio,tiene_paqueadero,nombre,flores):
  """
  Constructor de la clase floristeria
  Argumentos:
  color(str): definir el color de la casa
  num_habitaciones(int): definir el numero de habitaciones de la casa
  num_baños(int): numero de baños
  tiene_patio(bool): si tiene o no un patio
  tiene_parqueadero(bool): si tiene o no un parqueadero
  nombre(str): nombre de la floristeria
  flores(list): lista de flores
  """
  super().__init__(color,num_habitaciones,num_baños,tiene_patio,tiene_paqueadero)
  self.nombre=nombre
  self.flores=flores

 def describir_floristeria(self):
   descripcion_casa:
# Out:
#   File "/tmp/ipython-input-1878217137.py", line 1
#     class Floristeria(Casa): #Herencia
#                                       ^
# SyntaxError: incomplete input

# %%
mi_floriteria=Floristeria("amarilla",1,1,False,False,"Floristeria",["tulipan"])
