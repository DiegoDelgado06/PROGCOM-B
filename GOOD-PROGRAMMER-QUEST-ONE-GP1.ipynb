# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoDelgado06/PROGCOM-B/blob/main/GOOD-PROGRAMMER-QUEST-ONE-GP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Opciones extendidas
opciones_extendido = [
    "Piedra", "Papel", "Tijera", "Lagarto", "Spock",
    "Pistola", "Ninja", "Pirata", "Meteorito", "Carro",
    "Dragón", "Unicornio"
]

# Diccionario de reglas
reglas = {
    "Piedra":     ["Tijera", "Lagarto", "Pistola", "Meteorito", "Carro", "Dragón", "Unicornio"],
    "Papel":      ["Piedra", "Spock", "Pistola", "Meteorito", "Carro", "Dragón", "Unicornio"],
    "Tijera":     ["Papel", "Lagarto", "Pistola", "Ninja", "Carro", "Dragón", "Unicornio"],
    "Lagarto":    ["Spock", "Papel", "Pistola", "Pirata", "Carro", "Dragón", "Unicornio"],
    "Spock":      ["Tijera", "Piedra", "Pistola", "Ninja", "Carro", "Dragón", "Unicornio"],
    "Pistola":    ["Spock", "Lagarto", "Tijera", "Pirata", "Carro", "Dragón", "Unicornio"],
    "Ninja":      ["Pirata", "Papel", "Lagarto", "Pistola", "Carro", "Dragón", "Unicornio"],
    "Pirata":     ["Papel", "Spock", "Meteorito", "Ninja", "Carro", "Dragón", "Unicornio"],
    "Meteorito":  ["Piedra", "Tijera", "Lagarto", "Spock", "Carro", "Dragón", "Unicornio"],
    "Carro":      ["Piedra", "Papel", "Tijera", "Lagarto", "Spock", "Pistola", "Ninja", "Pirata", "Meteorito", "Dragón", "Unicornio"],
    "Dragón":     ["Piedra", "Papel", "Tijera", "Lagarto", "Spock", "Pistola", "Ninja", "Pirata", "Meteorito", "Carro"],
    "Unicornio":  ["Piedra", "Papel", "Tijera", "Lagarto", "Spock", "Pistola", "Ninja", "Pirata", "Meteorito", "Carro"]
}

# Marcadores
ganados = 0
perdidos = 0
empates = 0

print("¡Bienvenido a Piedra, Papel, Tijera EXTREMO! 🪨📄✂️🦎🖖 + más...\n")

while True:
    print("\nOpciones:")
    for i, opcion in enumerate(opciones_extendido, 1):
        print(f"{i}. {opcion}")

    try:
        eleccion_usuario = int(input("\nElige una opción (1-12) o 0 para salir: "))
        if eleccion_usuario == 0:
            break
        if eleccion_usuario < 1 or eleccion_usuario > len(opciones_extendido):
            print("Opción no válida. Intenta de nuevo.")
            continue
    except ValueError:
        print("Entrada inválida. Debe ser un número.")
        continue

    user = opciones_extendido[eleccion_usuario - 1]
    bot = random.choice(opciones_extendido)

    print(f"\nTú eliges: {user}")
    print(f"El bot elige: {bot}")

    if user == bot:
        resultado = "Empate"
        empates += 1
    elif bot in reglas[user]:
        resultado = "¡Ganaste!"
        ganados += 1
    else:
        resultado = "Perdiste"
        perdidos += 1

    print(f"\nResultado: {resultado}")
    print(f"Marcador: ✅ {ganados} | ❌ {perdidos} | 🤝 {empates}")

print("\nGracias por jugar 🎉")
# Out:
# ¡Bienvenido a Piedra, Papel, Tijera EXTREMO! 🪨📄✂️🦎🖖 + más...
#
#
# Opciones:
# 1. Piedra
# 2. Papel
# 3. Tijera
# 4. Lagarto
# 5. Spock
# 6. Pistola
# 7. Ninja
# 8. Pirata
# 9. Meteorito
# 10. Carro
# 11. Dragón
# 12. Unicornio
#
# Elige una opción (1-12) o 0 para salir: 8
#
# Tú eliges: Pirata
# El bot elige: Spock
#
# Resultado: ¡Ganaste!
# Marcador: ✅ 1 | ❌ 0 | 🤝 0
#
# Opciones:
# 1. Piedra
# 2. Papel
# 3. Tijera
# 4. Lagarto
# 5. Spock
# 6. Pistola
# 7. Ninja
# 8. Pirata
# 9. Meteorito
# 10. Carro
# 11. Dragón
# 12. Unicornio
#
# Elige una opción (1-12) o 0 para salir: 2
#
# Tú eliges: Papel
# El bot elige: Unicornio
#
# Resultado: ¡Ganaste!
# Marcador: ✅ 2 | ❌ 0 | 🤝 0
#
# Opciones:
# 1. Piedra
# 2. Papel
# 3. Tijera
# 4. Lagarto
# 5. Spock
# 6. Pistola
# 7. Ninja
# 8. Pirata
# 9. Meteorito
# 10. Carro
# 11. Dragón
# 12. Unicornio
#
# Elige una opción (1-12) o 0 para salir: 6
#
# Tú eliges: Pistola
# El bot elige: Piedra
#
# Resultado: Perdiste
# Marcador: ✅ 2 | ❌ 1 | 🤝 0
#
# ...
