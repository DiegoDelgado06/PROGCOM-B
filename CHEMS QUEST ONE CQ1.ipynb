# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoDelgado06/PROGCOM-B/blob/main/CHEMS%20QUEST%20ONE%20CQ1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
CAPTURA QUEST CHEMS TWO CQ1 (CON CHANCLE PERO AHORA OBLIGATORIO)

# %% [markdown]
# NOTA: Segun lo pactado en clase hasta el nivel 20 es gratuito el juego por ende se considera que no se resta experiencia.
# Solo aclaro lo pactado y aclarado en clase.
